# %% [markdown]
# # import libraries and load data

# %%
# Import modules
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import numpy as np
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# Figures inline and set visualization style
# %matplotlib inline
sns.set()

# Import data
df_train = pd.read_csv('data/train.csv')
df_test = pd.read_csv('data/test.csv')
print(df_train.head(1))
print(df_test.shape)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S
# (418, 11)

# %%
sns.countplot('Survived', data=df_train)

# %%
df_test['Survived'] = 0
df_test[['PassengerId', 'Survived']].to_csv('data/predictions/no_survivors.csv', index=False)

# %%
sns.factorplot(x='Survived', col='Sex', kind='count', data=df_train)

# %%
print(df_train.groupby('Sex').Survived.sum())
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
proportion_female_survived = 233/df_train[df_train.Sex == 'female'].Survived.count()
proportion_male_survived = 109/df_train[df_train.Sex == 'male'].Survived.count()
print('proportion of female_survived: {}'.format(proportion_female_survived))
print('proportion of male_survived: {}'.format(proportion_male_survived))
# Out:
# proportion of female_survived: 0.7420382165605095
# proportion of male_survived: 0.18890814558058924

# %%
df_test.loc[df_test.Sex == 'female', 'Survived'] = 1
print(df_test.head())
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q         0
# 1  47.0      1      0   363272   7.0000   NaN        S         1
# 2  62.0      0      0   240276   9.6875   NaN        Q         0
# 3  27.0      0      0   315154   8.6625   NaN        S         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         1

# %%
df_test[['PassengerId', 'Survived']].to_csv('data/predictions/women_survivors.csv', index=False)

# %%
df_train_drop = df_train.dropna()
sns.pairplot(df_train_drop, hue='Survived')
